# %% [markdown]
# ## Informe 2:
# ### DESESTACIONALIZACIÓN Y MODELIZACIÓN DE LA SERIE DE OCUPADOS PROVINCIALES
#
# #### Datos:
# Para la **misma provincia asignada en el informe 1**, recopile datos actualizados de afiliados a fin de mes y de ocupados (EPA).
#
# #### Parte 1: Desestacionalización de ocupados
# La primera parte del informe consiste en aplicar a la serie de ocupados de vuestra provincia (desde enero de 2008 hasta el último trimestre disponible) todas las técnicas de desestacionalización que conocéis (clásica aditiva, clásica multiplicativa, STL y, quizás, X13ARIMA-SEATS) y calcular cuál de ellas se aproxima más a la serie corregida por estacionalidad disponible en este [enlace](https://raw.githubusercontent.com/otoperalias/Coyuntura/main/clases/datos/informe2_ocupados_desest.csv). Para esto último, usad el coeficiente mape (mean absolute percentage error).
#
# -----
# Para el resto del informe, filtre los datos de ocupados de enero-2012 en adelante.
#
# -----
#
# #### Parte 2: Modelización SARIMA
# 1. Modelizad la serie de ocupados de vuestra provincia con el modelo SARIMA. Para analizar cómo de exacta es la capacidad de predecir de la serie, dividir esta en dos partes, una “training dataset” que abarque el periodo "1er Tr **2012**" - "4ºTr2023" y una “test dataset” con el resto (1erTr 2024- 3er Tr 2025). Cread un gráfico con la predicción y calculad el coeficiente mape y la correlación entre vuestra predicción y la test dataset.
# 2. Predecid hacia el futuro 4 periodos (desde el tercer 4º Tr 2025 – 3º Trim 2026). Crear un gráfico, incluyendo intervalos de confianza.
#
# #### Parte 3: Modelización SARIMAX
# 1. Modelizad la serie de ocupados de vuestra provincia con el modelo SARIMAX. Como variable exógena, usad la serie de afiliados de vuestra provincia. Para analizar cómo de exacta es la capacidad de predecir de la serie, haced lo mismo que lo indicado anteriormente en el apartado 2.1.
# 2. Predecid hacia el futuro 1 periodo (es decir, predecid el número de ocupados de vuestra provincia para el cuarto trimestre de 2025).

# %% [markdown]
# #### PRESENTACIÓN DEL INFORME
#
# El informe debe presentarse en un documento PDF siguiendo la plantilla que se muestra debajo. Además, debéis aportar el notebook de Jupyter utilizado para generar el informe.
# Observad que, en la figura, los axes ax1 y ax2 son para el título y para responder a la primera parte; el ax3 es para responder al apartado 2.1 (añadiendo un gráfico); el ax4 es para responder al apartado 2.2 (con un gráfico); el ax5 para responder al apartado 3.1 (con un gráfico), y el ax6 para responder al apartado 3.2 (con un gráfico).
# Ambos documentos deben enviarse a través del Aula Virtual antes del domingo 30 de noviembre a las 23:55.

# %%
# Plantilla básica para generar el Informe 2.

import matplotlib.pyplot as plt

fig,((ax1,ax2),(ax3,ax4),(ax5,ax6))=plt.subplots(3,2,figsize=(8.27,11.69)) # Una hoja A4 tiene ese tamaño, en pulgadas.

# Borro todos los ejes de los dos gráficos superiores
ax1.axis('off')
ax2.axis('off')

# Encabezado
fig.text(0.1,0.85,"INFORME 2", weight="bold", size=15)
fig.text(0.1,0.82,"MODELIZACIÓN DE LA SERIE DE OCUPADOS DE LA PROVINCIA DE XXXX", weight="bold", size=14)
fig.text(0.1,0.79,"Apellidos, Nombre", size=12)
fig.text(0.1,0.77,"Fecha: Noviembre de 2025", size=12)

# Parte 1:
fig.text(0.1,0.72,"PARTE 1: DESESTACIONALIZACIÓN DE LA SERIE DE OCUPADOS", weight="bold", size=13)
fig.text(0.1,0.67,"El método que más se aproxima a la serie corregida por estacionalidad de ocupados es el\n\
_________________, obteniendo un coeficiente mape igual a ____.", size=10.5)

# Parte 2
fig.text(0.1,0.62,"PARTE 2: PREDICCIÓN SARIMA", weight="bold", size=13)
ax3.plot()
ax3.text(0.6,0.25,"mape=...",transform=ax3.transAxes)
ax3.text(0.6,0.15,"Coef.corr=...",transform=ax3.transAxes)
ax4.plot()

# Parte 3
fig.text(0.1,0.33,"PARTE 3: PREDICCIÓN SARIMAX", weight="bold", size=13)
ax5.plot()
ax5.text(0.6,0.25,"mape=...",transform=ax5.transAxes)
ax5.text(0.6,0.15,"Coef.corr=...",transform=ax5.transAxes)
ax6.plot()
fig.text(0.1,0.04,"Según nuestra estimación del modelo SARIMAX, la tasa de variación interanual de ocupados\n\
para el cuarto trimestre de 2025 será del ___%.", size=10.5)
plt.subplots_adjust(hspace=0.4)
plt.savefig("Informe2.pdf",  bbox_inches='tight', pad_inches=0.5, format="pdf")
plt.show()
